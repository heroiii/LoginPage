# %%
from tkinter import *
from tkinter import ttk
from PIL import Image,ImageTk  #pip install pillow
from tkinter.messagebox import showerror
import tkinter as tk


class Login_Window():
    def __init__ (self,root):
    
        
        self.root = root
        self.root.title('Login')
        self.root.geometry('600x400')
        self.root.resizable(False,False)
        self.root.iconbitmap('01.ico')
        self.root.state('normal')

        
        self.bg = ImageTk.PhotoImage(file = '1.png')
        lbl_bg = Label(self.root,image = self.bg)
        lbl_bg.place(x = 0, y = 0, relwidth = 1,relheight = 1)
        
        frame = Frame(self.root,bg = 'black')
        frame.place(x = 320, y = 200, width = 340,height = 196)
        
        #for logo of office
        #img1 = Image.open('l1.png')
        #img1 = img1.resize((100,100),Image.ANTIALIAS)
        #self.photoimage1 = ImageTk.PhotoImage(img1)
        #lblimg1 = Label(frame,image = self.photoimage1,bg = 'black' ,borderwidth = 0)
        #lblimg1.place(x = 0,y = 0,width =100,height = 100)
        
        get_str = Label(frame , text = ' سیستم حسابداری صنعتی اندیشمند',fg = 'white',bg ='black')
        get_str.place(x = 60 , y =0)
        
        finy = Label(frame,text = 'سال مالی',bg = 'black',fg = 'white')
        finy.place(x = 210,y =30)
        
        self.txtfin = ttk.Entry(frame)
        self.txtfin.place(x = 145,y = 50)
        
        username = Label(frame,text = 'نام کاربر ',bg = 'black',fg = 'white')
        username.place(x = 190,y =80)
        
        self.txtuser = ttk.Entry(frame)
        self.txtuser.place(x = 145,y = 100)
        
        password = Label(frame,text = 'رمز ورود',bg = 'black',fg = 'white')
        password.place(x = 190,y =130)
        
        self.txtpass = ttk.Entry(frame,show="*")
        self.txtpass.place(x = 145,y = 150)
        
        img2 = Image.open('loginmanager.png')
        img2 = img2.resize((25,25),Image.ANTIALIAS)
        self.photoimage2 = ImageTk.PhotoImage(img2)
        lblimg2 = Label(frame,image = self.photoimage2,bg = 'black' ,borderwidth = 0)
        lblimg2.place(x = 245,y =75,width =25,height = 25)
        
        img3 = Image.open('keypassword.png')
        img3 = img3.resize((25,25),Image.ANTIALIAS)
        self.photoimage3 = ImageTk.PhotoImage(img3)
        lblimg3 = Label(frame,image = self.photoimage3,bg = 'black' ,borderwidth = 0)
        lblimg3.place(x = 245,y =122,width =25,height = 25)
        
        
       
        
        img4 = Image.open('Login.png')
        img4 = img4.resize((25,25),Image.ANTIALIAS)
        self.photoimage4 = ImageTk.PhotoImage(img4)
        lblimg4 = Label(frame,image = self.photoimage4,bg = 'black' ,borderwidth = 0)
        lblimg4.place(x = 5,y =130,width =50,height = 25)
        
        loginbtn = Button(frame,image = self.photoimage4,command = self.login ,activebackground='black',borderwidth = 0,bg = 'black')
        loginbtn.place(x = 5,y =130,width =50,height = 25)
        
        img5 = Image.open('set.png')
        img5 = img5.resize((25,25),Image.ANTIALIAS)
        self.photoimage5 = ImageTk.PhotoImage(img5)
        lblimg5 = Label(frame,image = self.photoimage5,bg = 'black' ,borderwidth = 0)
        lblimg5.place(x = 5,y =170,width =50,height = 25)
        
        
        setbtn = Button(frame,image = self.photoimage5,command = self.sett ,activebackground='black',borderwidth = 0,bg = 'black')
        setbtn.place(x = 5,y =170,width =50,height = 25)

        registerbtn = Button(frame,text = 'کاربر جدید' ,fg = 'white',command = self.register,activebackground='orange',borderwidth = 0,bg = 'black')
        registerbtn.place(x = 10,y =50,width =90,height = 25)
        
        forgetbtn = Button(frame,text = 'رمز فراموش شده',fg = 'white',command = self.forget,activebackground='orange',borderwidth = 0,bg = 'black')
        forgetbtn.place(x = 10,y =80,width =90,height = 25)

    def login(self):
      
        if self.txtuser.get()=='' or self.txtpass.get()=='':
            showerror('خطا','همه فیلدها پرشود لطفا')
        elif self.txtuser.get()=='admin' and self.txtpass.get()=='admin':
            self.app_window = Toplevel(self.root)
            
        else:
            showerror('خطا','نام کاربری یا رمز ورود اشتباه است')
            
    def register(self):
        self.root.state('withdrawn')
        self.new_window = Toplevel(self.root)
        self.app = Register_Window(self.new_window)
        
    def forget(self):
        self.root.state('withdrawn')
        self.new_window = Toplevel(self.root)
        self.app = Forget_Window(self.new_window )
        
        
    def sett(self):
        self.set_window = Toplevel(self.root)




class Register_Window():
    def __init__ (self,root):
        
        self.root = root
        self.root.title('Register')
        self.root.geometry('600x320')
        self.root.resizable(False,False)
        self.root.iconbitmap('01.ico')
        self.root.state('normal')

        
        self.bg = ImageTk.PhotoImage(file = 'register.png')
        lbl_bg = Label(self.root,image = self.bg,bg = 'gray')
        lbl_bg.place(x = 0, y = 0, relwidth = 1,relheight = 1)
        
        
        #for logo of office
        #img1 = Image.open('l1.png')
        #img1 = img1.resize((100,100),Image.ANTIALIAS)
        #self.photoimage1 = ImageTk.PhotoImage(img1)
        #lblimg1 = Label(frame,image = self.photoimage1,bg = 'black' ,borderwidth = 0)
        #lblimg1.place(x = 0,y = 0,width =100,height = 100)
        
        reg_name = Label(lbl_bg , text = ' ایجاد کاربر جدید',bg = 'lightgray',fg = 'black')
        reg_name.place(x = 500 , y =0)
        
        name = Label(lbl_bg,text = 'نام',bg = 'lightgray',fg = 'black')
        name.place(x = 500,y =30)
        
        self.txtname = ttk.Entry(lbl_bg)
        self.txtname.place(x = 370,y = 30)
        
        family = Label(lbl_bg,text = 'نام خانوادگی',bg = 'lightgray',fg = 'black')
        family.place(x = 500,y =60)
        
        self.txtfamily = ttk.Entry(lbl_bg)
        self.txtfamily.place(x = 370,y = 60)
        
        username = Label(lbl_bg,text = 'نام کاربر ',bg = 'lightgray',fg = 'black')
        username.place(x = 500,y =90)
        
        self.txtuser = ttk.Entry(lbl_bg)
        self.txtuser.place(x = 370,y = 90)
        
        password = Label(lbl_bg,text = 'رمز ورود',bg = 'lightgray',fg = 'black')
        password.place(x = 500,y =120)
        
        self.txtpass = ttk.Entry(lbl_bg,show="*")
        self.txtpass.place(x = 370,y = 120)
        
        img1 = Image.open('reg.png')
        img1 = img1.resize((70,30),Image.ANTIALIAS)
        self.photoimage1 = ImageTk.PhotoImage(img1)
        lblimg1 = Label(lbl_bg,image = self.photoimage1,bg = 'black' ,borderwidth = 0)
        lblimg1.place(x = 400,y =170,width =50,height = 25)
        
        
        regbtn = Button(lbl_bg,image = self.photoimage1 ,activebackground='black',borderwidth = 0,bg = 'black')
        regbtn.place(x = 400,y =170,width =70,height = 30)
        
        img2 = Image.open('log.png')
        img2 = img2.resize((70,30),Image.ANTIALIAS)
        self.photoimage2 = ImageTk.PhotoImage(img2)
        lblimg2 = Label(lbl_bg,image = self.photoimage2,bg = 'black' ,borderwidth = 0)
        lblimg2.place(x = 400,y =210,width =70,height = 30)
        
        
        logbtn = Button(lbl_bg,image = self.photoimage2 ,command = self.loginr,activebackground='black',borderwidth = 0,bg = 'black')
        logbtn.place(x = 400,y =210,width =70,height = 30)
        
    def loginr(self):
        self.root.state('withdrawn')
        self.new_window = Toplevel(self.root)
        self.app = Login_Window(self.new_window)

         
class Forget_Window():
    def __init__ (self,root):
        
        self.root = root
        self.root.title('Forget')
        self.root.geometry('350x500')
        self.root.resizable(False,False)
        self.root.iconbitmap('01.ico')
        self.root.state('normal')

        
        self.bg = ImageTk.PhotoImage(file = 'Frgt.png')
        lbl_bg = Label(self.root,image = self.bg,bg = 'gray')
        lbl_bg.place(x = 0, y = 0, relwidth = 1,relheight = 1)
        
        
        #for logo of office
        #img1 = Image.open('l1.png')
        #img1 = img1.resize((100,100),Image.ANTIALIAS)
        #self.photoimage1 = ImageTk.PhotoImage(img1)
        #lblimg1 = Label(frame,image = self.photoimage1,bg = 'black' ,borderwidth = 0)
        #lblimg1.place(x = 0,y = 0,width =100,height = 100)
        
        reg_name = Label(lbl_bg , text = ' بازیابی رمز عبور',bg = 'lightgray',fg = 'black')
        reg_name.place(x = 200 , y =0)
        
        name = Label(lbl_bg,text = 'نام',bg = 'lightgray',fg = 'black')
        name.place(x = 200,y =30)
        
        self.txtname = ttk.Entry(lbl_bg)
        self.txtname.place(x = 50,y = 30)
        
        family = Label(lbl_bg,text = 'نام خانوادگی',bg = 'lightgray',fg = 'black')
        family.place(x = 200,y =60)
        
        self.txtfamily = ttk.Entry(lbl_bg)
        self.txtfamily.place(x = 50,y = 60)
        
        username = Label(lbl_bg,text = 'نام کاربر ',bg = 'lightgray',fg = 'black')
        username.place(x = 200,y =90)
        
        self.txtuser = ttk.Entry(lbl_bg)
        self.txtuser.place(x = 50,y = 90)
        
        password = Label(lbl_bg,text = 'رمز جدید',bg = 'lightgray',fg = 'black')
        password.place(x = 200,y =120)
        
        self.txtpass = ttk.Entry(lbl_bg,show="*")
        self.txtpass.place(x = 50,y = 120)
        
        password = Label(lbl_bg,text = 'رمز جدید',bg = 'lightgray',fg = 'black')
        password.place(x = 200,y =150)
        
        self.txtpass = ttk.Entry(lbl_bg,show="*")
        self.txtpass.place(x = 50,y = 150)
        
        
        img1 = Image.open('reg.png')
        img1 = img1.resize((70,30),Image.ANTIALIAS)
        self.photoimage1 = ImageTk.PhotoImage(img1)
        lblimg1 = Label(lbl_bg,image = self.photoimage1,bg = 'black' ,borderwidth = 0)
        lblimg1.place(x = 100,y =190,width =50,height = 25)
        
        
        regbtn = Button(lbl_bg,image = self.photoimage1 ,activebackground='black',borderwidth = 0,bg = 'black')
        regbtn.place(x = 100,y =190,width =70,height = 30)
        
        img2 = Image.open('log.png')
        img2 = img2.resize((70,30),Image.ANTIALIAS)
        self.photoimage2 = ImageTk.PhotoImage(img2)
        lblimg2 = Label(lbl_bg,image = self.photoimage2,bg = 'black' ,borderwidth = 0)
        lblimg2.place(x = 100,y =230,width =70,height = 30)
        
        
        logbtn = Button(lbl_bg,image = self.photoimage2,command = self.loginf ,activebackground='black',borderwidth = 0,bg = 'black')
        logbtn.place(x = 100,y =230,width =70,height = 30)
        
    def loginf(self):
        self.root.state('withdrawn')
        self.new_window = Toplevel(self.root)
        self.app = Login_Window(self.new_window)




        


if __name__ == '__main__':
    root=Tk()
    app = Login_Window(root)
    root.mainloop()
# Out:
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:62: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:71: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
# ...

# %% [markdown]
# #####
